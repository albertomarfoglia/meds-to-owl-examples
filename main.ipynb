# %% [markdown]
# <!-- # Convert NEUROVASC into MEDS-OWL -->

# %%
import os
import joblib

NEUROVASC = "NEUROVASC"
ETL_OUTPUT = f"{NEUROVASC}/MEDS_cohort"
ETL_INTERMEDIATE = f"{NEUROVASC}/pre_MEDS"
ETL_INPUT = f"{NEUROVASC}/raw_input"
ETL_GRAPH = f"{NEUROVASC}/graph"
EXPORT_DIR = "exports/neurovasc/graph"
ETL_LABELS = f"{EXPORT_DIR}/labels"

os.makedirs(ETL_INPUT, exist_ok=True)
os.makedirs(ETL_INTERMEDIATE, exist_ok=True)
os.makedirs(ETL_OUTPUT, exist_ok=True)
os.makedirs(ETL_GRAPH, exist_ok=True)
os.makedirs(ETL_LABELS, exist_ok=True)

NUM_PATIENTS = 10000
TIME_OPT = "TS"
SYN_NEUROVASC_DATA = "https://raw.githubusercontent.com/TeamHeKA/neurovasc/refs/heads/main/exp/data/syn_data_10000.csv"

# %% [markdown]
# ### a) Load/Generate source dataset

# %%
import pandas as pd

# from NEUROVASC.utils.synthetic_generator import generate_synthetic_dataset
# df_input = generate_synthetic_dataset(NUM_PATIENTS, output_csv=f"{ETL_INPUT}/syn_data.csv")
df_input = pd.read_csv(SYN_NEUROVASC_DATA, index_col=0)
df_input = df_input.sample(frac=1, random_state=42).reset_index(drop=True)
df_input = df_input.rename(columns={"output": "outcome"})

# %% [markdown]
# ### b) Preprocess the source dataset

# %%
from NEUROVASC.utils.pre_MEDS import generate_meds_preprocessed

joblib.dump(
    df_input["outcome"].astype(int).to_list(),
    f"{ETL_LABELS}/outcomes_meds_{TIME_OPT}_{NUM_PATIENTS}.joblib",
)

df_input_outcome = df_input.iloc[0:NUM_PATIENTS]
df_input_no_outcome = df_input_outcome.drop(columns=["outcome"])
generate_meds_preprocessed(df_input_no_outcome, output_path=ETL_INTERMEDIATE)

print("Neurovasc data ready for MEDS-Extract")

# %% [markdown]
# ### c) Run MEDS_Extract ETL to convert source into MEDS

# %%
from MEDS_transforms.runner import main
import shutil

shutil.rmtree(ETL_OUTPUT)

main(
    [
        "pkg://MEDS_extract.configs._extract.yaml",
        "--overrides",
        f"input_dir={ETL_INTERMEDIATE}",
        f"output_dir={ETL_OUTPUT}",
        f"event_conversion_config_fp={NEUROVASC}/MESSY.yaml",
        "dataset.name=Neurovasc",
        "dataset.version=1.0",
    ]
)

# %% [markdown]
# ### d) Convert NEUROVASC_MEDS into KG through MEDS2RDF

# %%
from pathlib import Path

from meds2rdf import MedsRDFConverter
from meds2rdf.sinks import NTriplesSink
from meds2rdf.config import Config, MEDSSchema

shacl_graph = "https://raw.githubusercontent.com/TeamHeKA/meds-ontology/refs/heads/main/shacl/meds-shapes.ttl"

engine = MedsRDFConverter(ETL_OUTPUT)


engine.convert(
    sink=NTriplesSink((Path(EXPORT_DIR) / f"meds_{NUM_PATIENTS}"), gzip_mode=False),
    cfg=Config(schemas={MEDSSchema.CODES}),
)

# sink = GraphSink(graph=Graph())
# sink.graph.serialize(f"{ETL_GRAPH}/meds_{TIME_OPT}_{NUM_PATIENTS}.nt", format="nt")

# %%
import glob
import gzip
from rdflib import Graph

g = Graph()

for path in glob.glob(f"{EXPORT_DIR}/*.nt.gz"):
    with gzip.open(path, "rt", encoding="utf-8") as f:
        g.parse(f, format="nt")

# %% [markdown]
# ### e) Compute metrics [OPTIONAL]

# %%
from NEUROVASC.utils.metrics import (
    compute_MEDS_graph_metrics_for_neurovasc,
    save_stats_json,
)
from pathlib import Path

stats = compute_MEDS_graph_metrics_for_neurovasc(
    MEDS_ETL_output_path=ETL_OUTPUT,
    graph=g,
    tabular_data=df_input_no_outcome,
    MEDS_intermediate=Path(ETL_INTERMEDIATE),
)

save_stats_json(stats, f"{ETL_OUTPUT}/metrics/all_metrics_2.json")

# %% [markdown]
# ### f) Compute consistency checks [OPTIONAL]

# %%
import polars as pl
from NEUROVASC.utils.neurovasc_meta import EVENTS_COLUMNS
from NEUROVASC.utils.transformers import (
    build_neurovasc_meds_dt,
    build_neurovasc_medskg_dt,
    check_dts_consistency,
)

synt_df = df_input.copy()
synt_df[EVENTS_COLUMNS] = (synt_df[EVENTS_COLUMNS] > -1).astype(int)

mimic_outcomes = joblib.load(
    f"{ETL_GRAPH}/outcomes_meds_{TIME_OPT}_{NUM_PATIENTS}.joblib"
)

meds_data = pl.read_parquet(str(f"{ETL_OUTPUT}/data/**/*.parquet")).to_dicts()
meds_df = build_neurovasc_meds_dt(meds_data)
meds_df = meds_df.astype(synt_df.dtypes.to_dict())
meds_df["outcome"] = mimic_outcomes

graph_df = build_neurovasc_medskg_dt(g)
graph_df = graph_df.astype(synt_df.dtypes.to_dict())
graph_df["outcome"] = mimic_outcomes


def remove_digits(_df: pd.DataFrame):
    _df["hospital_stay_length"] = _df["hospital_stay_length"].round()
    _df["nb_acte"] = _df["nb_acte"].round()
    _df["age"] = _df["age"].round()
    _df["gcs"] = _df["gcs"].round(2)


for _df in [synt_df, meds_df, graph_df]:
    remove_digits(_df)

check_dts_consistency(meds_df, synt_df)
check_dts_consistency(meds_df, graph_df)
check_dts_consistency(graph_df, synt_df)

# %% [markdown]
# # Convert MIMIC-IV Demo into MEDS-OWL
# [link](https://physionet.org/content/mimic-iv-demo-meds/0.0.1/) to Physionet repository

# %%
# !bash MIMIC/run.sh

# %%
import os

MIMIC_TASKS_PATH = "MIMIC/tasks"

for f in os.listdir(MIMIC_TASKS_PATH):
    f_name = os.path.splitext(f)[0]
    # !aces-cli \
        config_path="{MIMIC_TASKS_PATH}/{f}" \
        cohort_name="{f_name}" \
        cohort_dir="{MIMIC_ETL_OUTPUT}/labels" \
        data=sharded \
        data.standard=meds \
        data.root="{MIMIC_ETL_OUTPUT}/data" \
        data.shard=$(expand_shards train/292 tuning/37 held_out/37) \
        -m

# %%
MIMIC_COHORT = "MIMIC/MEDS_cohort"

from MIMIC.utilities import PREFIX_MAP, process_codes

process_codes(
    input_parquet=f"{MIMIC_COHORT}/metadata/codes.parquet",
    output_dir="mimic_external_codes",
    prefix_map=PREFIX_MAP,
)

# %%
import yaml
import os
import polars as pl

MIMIC_COHORT = "MIMIC/MEDS_cohort"
TIME_OPT = "TS"


def init_dirs(task_name: str, index: int):
    export_dir = f"exports/{task_name}"
    graph_dir = f"{export_dir}/graph"
    outcomes_dir = f"{graph_dir}/labels"
    meds_cohort_dir = f"{export_dir}/meds/{index}/MEDS_cohort"
    os.makedirs(export_dir, exist_ok=True)
    os.makedirs(graph_dir, exist_ok=True)
    os.makedirs(outcomes_dir, exist_ok=True)
    os.makedirs(meds_cohort_dir, exist_ok=True)
    os.makedirs(f"{export_dir}/meds/{index}/MEDS_cohort/metadata", exist_ok=True)

    return graph_dir, outcomes_dir, meds_cohort_dir


with open("MIMIC/experiments.yaml", "r") as f:
    config = yaml.safe_load(f)

events = pl.scan_parquet(f"{MIMIC_COHORT}/data/**/*.parquet", low_memory=True).select(
    "subject_id", "time", "code", "numeric_value", "text_value"
)

# %%
from MIMIC.utilities import generate_samples
from MIMIC.utilities import *
import numpy as np
import joblib
from meds2rdf import MedsRDFConverter, NTriplesSink, Config, MEDSSchema

columns = [
    "subject_id",
    "code",
    "time",
    "numeric_value",
    "prediction_time",
    "boolean_value",
]

for group_name, experiments in config["experiments"].items():
    print(f"\n=== Group: {group_name} ===")

    for scfg in experiments:
        print(f"Running task: {scfg['task']}")

        if scfg["task"] != "first_24_in_hospital_mortality":
            continue

        IHM = f"{MIMIC_COHORT}/labels/{scfg['task']}/**/*.parquet"
        outcomes = pl.scan_parquet(IHM).select(
            "subject_id", "prediction_time", "boolean_value"
        )

        samples = generate_samples(
            labels=outcomes,
            n_folds=scfg["num_of_samples"],
            size=scfg["sample_size"],
            seed=1234,
            low_true_values=scfg["fixed_true"],
        )

        for index, sample in enumerate([samples[0]]):
            graph_dir, outcomes_dir, meds_cohort_dir = init_dirs(scfg["task"], index)

            events_base = (
                events.join(sample.lazy(), on="subject_id", how="inner")
                .with_columns(remove_long_text)
                .with_columns(birthdate_to_age)
                .filter(window_dict[scfg["window"]])
            )

            events_base = (
                # events_base.join(freq_codes_v(events_base, freq=100), on="code", how="semi")
                events_base.with_columns(parsed=parse_txt_to_float)
                .with_columns(swap_text_with_numeric)
                .with_columns(orig_code=pl.col("code"), orig_text=pl.col("text_value"))
                .with_columns(bp_values=bp_values_list)
                .explode("bp_values")
                .with_columns(numeric_value=pl.col("bp_values"))
                .with_columns(code=to_systolic_and_dyastolic_pressure)
                .with_columns(text_value=set_BP_values_text_to_null)
                .drop(derived_columns)
                .with_columns(regenerate_ids)
            ).select(columns)

            # events_base = aggregate_events(events_base, agg=scfg["agg"]).collect(engine="streaming")

            TRESHOLD = 3  # max(1, int(np.ceil(scfg["sample_size"] * 0.00)))

            static_events = (
                events_base.filter(
                    pl.col("time").is_null() & pl.col("numeric_value").is_null()
                )
                .sort(["subject_id", "code"])
                .unique(subset=["subject_id", "code"], keep="last")
            )

            static_numeric_events = (
                events_base.filter(
                    pl.col("time").is_null() & pl.col("numeric_value").is_not_null()
                )
                .sort(["subject_id", "code"])
                .unique(subset=["subject_id", "code"], keep="last")
            )

            dynamic_numeric = (
                events_base.filter(
                    pl.col("time").is_not_null() & pl.col("numeric_value").is_not_null()
                )
                .with_columns(pl.col("time").dt.truncate(scfg["agg"]).alias("time"))
                .sort(["subject_id", "code", "time"])
                .group_by(["subject_id", "code", "time"])
                .agg(
                    [
                        pl.col("numeric_value").mean().alias("mean"),
                        pl.col("numeric_value").min().alias("min"),
                        pl.col("numeric_value").max().alias("max"),
                        # pl.col("text_value").first(),
                        pl.col("prediction_time").last(),
                        pl.col("boolean_value").last(),
                    ]
                )
            )

            EPS = 1e-6

            dynamic_numeric = dynamic_numeric.with_columns(
                [
                    pl.when((pl.col("min") - pl.col("mean")).abs() > EPS)
                    .then(pl.col("min"))
                    .otherwise(None)
                    .alias("min"),
                    pl.when((pl.col("max") - pl.col("mean")).abs() > EPS)
                    .then(pl.col("max"))
                    .otherwise(None)
                    .alias("max"),
                ]
            )

            dynamic_numeric = (
                dynamic_numeric.unpivot(
                    index=[
                        "subject_id",
                        "code",
                        "time",
                        # "text_value",
                        "prediction_time",
                        "boolean_value",
                    ],
                    on=["min", "mean", "max"],
                    variable_name="stat",
                    value_name="numeric_value",
                )
                .with_columns(
                    pl.concat_str([pl.col("code"), pl.lit("_"), pl.col("stat")]).alias(
                        "code"
                    )
                )
                .drop("stat")
            ).filter(pl.col("numeric_value").is_not_null())

            dynamic_numeric_codes = (
                dynamic_numeric.group_by(["subject_id", "code"])
                .len()
                .group_by("code")
                .len()
                .filter(pl.col("len") > 10)
            )

            # dynamic_numeric = dynamic_numeric.join(
            #     dynamic_numeric_codes.select("code"), on="code", how="inner"
            # )

            dynamic_codes = (
                events_base.filter(
                    pl.col("time").is_not_null() & pl.col("numeric_value").is_null()
                )
                # .group_by(["subject_id", "code"])
                # .agg(
                #     [
                #         pl.col("time").last().alias("time"),
                #         pl.len().cast(pl.Float64).alias("numeric_value"),
                #         pl.col("prediction_time").last().alias("prediction_time"),
                #         pl.col("boolean_value").last().alias("boolean_value"),
                #     ]
                # )
            )  # aggregare i codici per frequenza per paziente ed escludere quelli sotto una certa soglia (10%)

            dynamic_code_codes = (
                dynamic_codes.group_by(["subject_id", "code"])
                .len()
                .group_by("code")
                .len()
                .filter(pl.col("len") > 3)
            )

            # dynamic_codes = dynamic_codes.join(
            #     dynamic_code_codes.select("code"), on="code", how="inner"
            # )

            final_events = pl.concat(
                [
                    static_numeric_events.select(columns),
                    dynamic_numeric.select(columns),
                    dynamic_codes.select(columns),
                    static_events.select(columns),
                ],
            )

            final_events = aggregate_events(final_events, agg=scfg["agg"]).collect(
                engine="streaming"
            )

            print(f"TOTAL EVENTS: {len(final_events)}")
            print(f"TOTAL CODES: {len(final_events.group_by('code').len())}")

            (_, _, split_l) = create_meds_cohort(
                final_events,
                orig_dir=MIMIC_COHORT,
                output_dir=meds_cohort_dir,
                columns=["subject_id", "code", "time", "numeric_value"],
            )

            joblib.dump(
                value=split_l.sort("subject_id")["boolean_value"].to_numpy(),
                filename=f"{outcomes_dir}/outcomes_meds_{TIME_OPT}_{scfg['sample_size']}_{index}.joblib",
            )

            MedsRDFConverter(meds_cohort_dir).convert(
                sink=NTriplesSink(
                    Path(f"{graph_dir}/meds_{scfg['sample_size']}_{index}"),
                    gzip_mode=False,
                ),
                cfg=Config(schemas={MEDSSchema.CODES}),
            )

# %% [markdown]
# ### Display code statistics

# %%
import matplotlib.pyplot as plt

df = (
    dynamic_numeric.collect(engine="streaming")
    .group_by("code")
    .len()
    .filter(pl.col("len") > 10)
)

print(df.describe())

display(df)

pdf = df.to_pandas()
plt.hist(pdf["len"], bins=100)
plt.xlabel("Event count per code")
plt.ylabel("Frequency")
plt.title("Distribution of events per code")
plt.yscale("log")  # important due to heavy skew
plt.show()

plt.hist(np.log1p(pdf["len"]), bins=100)
plt.xlabel("log(1 + count)")
plt.ylabel("Frequency")
plt.title("Log-distribution of events per code")
plt.show()

counts = pdf["len"].sort_values(ascending=False).values

plt.plot(counts)
plt.yscale("log")
plt.xlabel("Code rank")
plt.ylabel("Frequency")
plt.title("Long-tail distribution (Zipf-like)")
plt.show()

counts = np.sort(pdf["len"].values)[::-1]
cum = np.cumsum(counts) / np.sum(counts)

plt.plot(cum)
plt.xlabel("Top-K codes")
plt.ylabel("Cumulative coverage")
plt.title("Coverage vs number of codes")
plt.show()

# %% [markdown]
# ### Aggregate MEDS-TAB results

# %%
import polars as pl
from pathlib import Path
import yaml
from MIMIC.utilities import (
    compute_metrics,
    aggregate_metrics,
    pretty_metrics_to_csv,
    get_metrics_file_path,
)

with open("MIMIC/experiments.yaml", "r") as f:
    config = yaml.safe_load(f)

tasks_metrics: dict = {}

for group_name, experiments in config["experiments"].items():
    print(f"\n=== Group: {group_name} ===")

    if group_name != "phenotyping":
        continue

    for scfg in experiments:
        task = scfg["task"]
        print(f"Running task: {task}")

        tasks_metrics[task] = []

        for i in range(scfg["num_of_samples"]):
            file_path = get_metrics_file_path(
                base_path=Path(
                    f"exports/{task}/meds/{i}/MEDS_cohort/output_model/{task}"
                )
            )

            if file_path is None:
                continue

            df = pl.read_parquet(file_path)

            y_true = df["boolean_value"].to_numpy()
            y_pred = df["predicted_boolean_value"].to_numpy()
            y_proba = df["predicted_boolean_probability"].to_numpy()

            tasks_metrics[task].append(compute_metrics(y_true, y_pred, y_proba))

pretty_metrics_to_csv(
    metrics=aggregate_metrics(tasks_metrics),
    output_path=Path("MIMIC/xgboost_metrics_summary.csv"),
)

# %% [markdown]
# ### Convert MIMIC MEDS into tabular format

# %% [markdown]
# ### Train XGBoost classifier

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from utils import build_features

# ROOT = "exports/first_24_in_hospital_mortality/meds/0/MEDS_cohort"

ROOT = "NEUROVASC2/MEDS_cohort"

df1 = build_features(pl.read_parquet(f"{ROOT}/data/train/0.parquet"))
df2 = build_features(pl.read_parquet(f"{ROOT}/data/tuning/0.parquet"))
df3 = build_features(pl.read_parquet(f"{ROOT}/data/held_out/0.parquet"))

l1 = pl.read_parquet(f"{ROOT}/labels/train/0.parquet")
l2 = pl.read_parquet(f"{ROOT}/labels/tuning/0.parquet")
l3 = pl.read_parquet(f"{ROOT}/labels/held_out/0.parquet")

x_train = (
    df1.sort(pl.col("subject_id")).to_pandas().select_dtypes(exclude=["datetime64[ns]"])
)
y_train = l1.sort(pl.col("subject_id"))["boolean_value"]

X_tuning = (
    df2.sort(pl.col("subject_id")).to_pandas().select_dtypes(exclude=["datetime64[ns]"])
)
y_tuning = l2.sort(pl.col("subject_id"))["boolean_value"]

X_held = (
    df3.sort(pl.col("subject_id")).to_pandas().select_dtypes(exclude=["datetime64[ns]"])
)
y_held = l3.sort(pl.col("subject_id"))["boolean_value"]

x_train = pd.get_dummies(x_train).drop(columns=["subject_id"])
X_tuning = (
    pd.get_dummies(X_tuning)
    .drop(columns=["subject_id"])
    .reindex(columns=x_train.columns, fill_value=0)
)
X_held = (
    pd.get_dummies(X_held)
    .drop(columns=["subject_id"])
    .reindex(columns=x_train.columns, fill_value=0)
)

feature_names = x_train.columns.to_list()

model = XGBClassifier(
    n_estimators=400,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    eval_metric="auc",
    feature_names=feature_names,
)

model.fit(x_train, y_train, eval_set=[(X_tuning, y_tuning)], verbose=False)

y_score_tuning = model.predict_proba(X_tuning)[:, 1]
y_score_held = model.predict_proba(X_held)[:, 1]

y_pred_tuning = (y_score_tuning >= 0.5).astype(int)
y_pred_held = (y_score_held >= 0.5).astype(int)

print("Tuning Accuracy:", accuracy_score(y_tuning, y_pred_tuning))
print("Held-out Accuracy:", accuracy_score(y_held, y_pred_held))

auroc_tuning = roc_auc_score(y_tuning, y_score_tuning)
auroc_held = roc_auc_score(y_held, y_score_held)

print("Tuning AUROC:", auroc_tuning)
print("Held-out AUROC:", auroc_held)

# %%
first_parts = [s.split("//")[0] for s in feature_names]

# %% [markdown]
# ### Explain XGBoost results

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_held)

shap.summary_plot(shap_values, X_held[feature_names])

i = 0
shap.force_plot(
    explainer.expected_value, shap_values[i], X_held.iloc[i], matplotlib=True
)

shap.plots.waterfall(
    shap.Explanation(
        values=shap_values[i],
        base_values=explainer.expected_value,
        data=X_held.iloc[i],
        feature_names=X_held.columns,
    )
)

# %%
import polars as pl
from pathlib import Path
import yaml

with open("MIMIC/experiments.yaml", "r") as f:
    config = yaml.safe_load(f)

tasks_metrics: dict = {}

for group_name, experiments in config["experiments"].items():
    print(f"\n=== Group: {group_name} ===")

    for scfg in experiments:
        task = scfg["task"]
        print(f"Running task: {task}")

        for i in range(scfg["num_of_samples"]):
            base_path = f"exports/{task}/meds/{i}/MEDS_cohort/"

            df = pl.read_parquet(base_path)


pretty_metrics_to_csv(
    metrics=aggregate_metrics(tasks_metrics),
    output_path=Path("MIMIC/xgboost_metrics_summary.csv"),
)

# %%
# TODO
# [] include more aggregation features (eg. count/code min/value, etc.)
# [] increase the number of patients making the dataset a little bit unbalanced
# [] if the true_values field is fixed I should sample each time different sample

# %%
# Can be runned only with the demo version of MIMIC

# from rdflib import Graph
# from NEUROVASC.utils.metrics import compute_MEDS_graph_metrics, save_stats_json

# MIMIC_OUTPUT_GRAPH = f"{MIMIC_ETL_GRAPH}/meds_{TIME_OPT}_{NUM_PATIENTS}.nt"

# g = Graph()
# g.parse(MIMIC_OUTPUT_GRAPH, format="nt")

# stats = compute_MEDS_graph_metrics(
#     MEDS_ETL_output_path=MIMIC_ETL_OUTPUT,
#     graph=g,
# )

# save_stats_json(stats, f"{MIMIC_ETL_OUTPUT}/metrics/all_metrics.json")

# %% [markdown]
# # NEUROVASC 2.0

# %%
import os

N2 = "NEUROVASC2"
N2_ETL_OUTPUT = f"{N2}/MEDS_cohort"
N2_ETL_INTERMEDIATE = f"{N2}/pre_MEDS"
N2_ETL_INPUT = f"{N2}/raw_input"

EXPORT_DIR = "exports/neurovasc_v2/graph"
ETL_LABELS = f"{EXPORT_DIR}/labels"

os.makedirs(N2_ETL_INPUT, exist_ok=True)
os.makedirs(N2_ETL_INTERMEDIATE, exist_ok=True)
os.makedirs(N2_ETL_OUTPUT, exist_ok=True)
os.makedirs(EXPORT_DIR, exist_ok=True)
os.makedirs(ETL_LABELS, exist_ok=True)

TIME_OPT = "TS"

# %%
import polars as pl

# df_input = pl.read_csv(f"{N2_ETL_INPUT}/synthetic_data_sdv.csv")
df_input = pl.read_csv(
    f"{N2_ETL_INPUT}/synthetic_data.csv",
    ignore_errors=True,
    schema_overrides={"Unstable_Intracranial_Aneurysm": pl.Utf8},
)
df_input = df_input.filter(pl.col("Outcome").is_not_null())

NUM_PATIENTS = len(set(df_input["Patient_ID"]))

# %%
pl.DataFrame({"column_name": sorted(df_input.columns)}).write_csv(
    "sorted_columns_real.csv"
)

# %%
from NEUROVASC2.pre_MEDS import generate_meds_preprocessed
import joblib

(contextual, sequential, outcomes) = generate_meds_preprocessed(
    df_input.to_pandas(),
    output_path=N2_ETL_INTERMEDIATE,
    outcome_path=f"{ETL_LABELS}/outcomes_meds_{TIME_OPT}_{NUM_PATIENTS}.joblib",
    synthetic=True,
)

joblib.dump(
    outcomes.to_list(),
    f"{ETL_LABELS}/outcomes_sphn_pc_{TIME_OPT}_{NUM_PATIENTS}.joblib",
)

print("Neurovasc 2 data ready for MEDS-Extract")

# %%
display(
    df_input
    .group_by("Patient_ID")
    .first()
    .group_by("Outcome")
    .len()
    .sort(by="Outcome")
)

# %%
# TODO To remove at the end
all_columns = set(contextual.columns) | set(sequential.columns)

pl.DataFrame({"column_name": sorted(all_columns)}).write_csv(
    "sorted_columns_real_prepro.csv"
)

# %%
from MEDS_transforms.runner import main
import shutil

shutil.rmtree(N2_ETL_OUTPUT)

main(
    [
        "pkg://MEDS_extract.configs._extract.yaml",
        "--overrides",
        f"input_dir={N2_ETL_INTERMEDIATE}",
        f"output_dir={N2_ETL_OUTPUT}",
        f"event_conversion_config_fp={N2}/MESSY.yaml",
        "dataset.name=Neurovasc_v2",
        "dataset.version=2.0",
    ]
)

# %%
# TODO To remove at the end
nn = [
    "Glasgow_Coma_Scale_Temporal",
    "Weight",
    "Number_of_Visited_Departments",
    "Length_of_Stay",
    "Glasgow_Coma_Scale",
    "Fisher_Score",
    "WFNS_Score",
]

a = (
    pl.read_parquet(f"{N2_ETL_OUTPUT}/data/**/0.parquet")
    .filter(
        (
            pl.col("code").str.split("//").list.get(0).is_in(nn)
            & pl.col("numeric_value").is_null()
        )
    )
    .group_by(["code"])
    .len()
    .with_columns((pl.col("len") / NUM_PATIENTS).alias("len"))
)

display(a)


# "WFNS_Score"	0.161241
# "Glasgow_Coma_Scale"	0.23913
# "Weight//Kg"	0.24208
# "Fisher_Score"	0.088486

# "WFNS_Score"	0.184739
# "Glasgow_Coma_Scale"	0.345382
# "Weight//Kg"	0.502008
# "Fisher_Score"	0.106426

# %%
# TODO To remove at the end

import polars as pl

pl.read_parquet(f"{N2_ETL_OUTPUT}/data/**/0.parquet").select(pl.col("code")).group_by(
    pl.col("code")
).n_unique().with_columns(
    pl.col("code").str.split("//").list.first().alias("code_prefix")
).group_by(pl.col("code_prefix")).n_unique().select("code_prefix").sort(
    by="code_prefix"
).write_csv("sorted_meds_columns.csv")

# %%
def remove_numeric_null(dt: pl.DataFrame) -> pl.DataFrame:
    nn = [
        # "Glasgow_Coma_Scale_Temporal",
        "Weight",
        # "Number_of_Visited_Departments",
        # "Length_of_Stay",
        "Glasgow_Coma_Scale",
        "Fisher_Score",
        "WFNS_Score",
    ]

    return dt.filter(
        ~(
            pl.col("code").str.split("//").list.get(0).is_in(nn)
            & pl.col("numeric_value").is_null()
        )
    )


remove_numeric_null(
    pl.read_parquet(f"{N2_ETL_OUTPUT}/data/train").filter(
        ~pl.col("code").str.contains("UNK")
    )
).write_parquet(f"{N2_ETL_OUTPUT}/data/train/0.parquet")
remove_numeric_null(
    pl.read_parquet(f"{N2_ETL_OUTPUT}/data/held_out").filter(
        ~pl.col("code").str.contains("UNK")
    )
).write_parquet(f"{N2_ETL_OUTPUT}/data/held_out/0.parquet")
remove_numeric_null(
    pl.read_parquet(f"{N2_ETL_OUTPUT}/data/tuning").filter(
        ~pl.col("code").str.contains("UNK")
    )
).write_parquet(f"{N2_ETL_OUTPUT}/data/tuning/0.parquet")

# %%
print(len(pl.read_parquet(f"{N2_ETL_OUTPUT}/data/**/0.parquet")))

# %%
from meds2rdf import MedsRDFConverter
from meds2rdf.sinks import NTriplesSink
from meds2rdf.config import Config, MEDSSchema
from pathlib import Path

engine = MedsRDFConverter(N2_ETL_OUTPUT)

engine.convert(
    sink=NTriplesSink((Path(EXPORT_DIR) / f"meds_{NUM_PATIENTS}"), gzip_mode=False),
    cfg=Config(schemas={MEDSSchema.CODES}),
)

# %%
import polars as pl
import pandas as pd
import numpy as np
from utils import build_features, evaluate_multiclass_model, mean_std_metrics
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
import joblib
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

ROOT = "NEUROVASC2/MEDS_cohort"

df = build_features(pl.read_parquet(f"{ROOT}/data/**/0.parquet"))
X = df.sort("subject_id").to_pandas().select_dtypes(exclude=["datetime64[ns]"])
X = pd.get_dummies(X).drop(columns=["subject_id"])
y = np.array(
    joblib.load(f"{ETL_LABELS}/outcomes_sphn_pc_{TIME_OPT}_{NUM_PATIENTS}.joblib")
)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

feature_names = X.columns.to_list()

models = {
    "xgboost": XGBClassifier(
        n_estimators=400,
        max_depth=6,
        learning_rate=0.05,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1,
        objective="multi:softprob",
        num_class=3,
        eval_metric="mlogloss",
        #feature_names=feature_names,
    ),
    # "rf": RandomForestClassifier(
    #     n_estimators=500,
    #     max_depth=10,
    #     random_state=42,
    #     n_jobs=-1,
    # ),
    # "lr": Pipeline(
    #     [
    #         ("imputer", SimpleImputer(strategy="median")),
    #         ("scaler", StandardScaler()),
    #         (
    #             "classifier",
    #             LogisticRegression(
    #                 # multi_class="multinomial",
    #                 solver="lbfgs",
    #                 max_iter=5000,
    #                 class_weight="balanced",
    #                 random_state=42,
    #                 n_jobs=-1,
    #             ),
    #         ),
    #     ]
    # ),
    # "mlp": Pipeline(
    #     [
    #         ("imputer", SimpleImputer(strategy="median")),
    #         ("scaler", StandardScaler()),
    #         (
    #             "classifier",
    #             MLPClassifier(
    #                 hidden_layer_sizes=(256, 128),
    #                 activation="relu",
    #                 solver="adam",
    #                 alpha=1e-4,
    #                 batch_size=32,
    #                 learning_rate_init=1e-3,
    #                 max_iter=500,
    #                 early_stopping=True,
    #                 validation_fraction=0.1,
    #                 n_iter_no_change=20,
    #                 random_state=42,
    #                 verbose=False,
    #             ),
    #         ),
    #     ]
    # ),
}

best_score = -np.inf
best_fold = None
best_model = None

for model_name, model in models.items():
    RESULTS = f"{EXPORT_DIR}/metrics_{NUM_PATIENTS}/{model_name}"

    os.makedirs(RESULTS, exist_ok=True)
    os.makedirs(f"{RESULTS}/cm", exist_ok=True)
    os.makedirs(f"{RESULTS}/models", exist_ok=True)

    all_metrics = []

    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        x_train = X.iloc[train_idx]
        x_val = X.iloc[val_idx]

        y_train = y[train_idx]
        y_val = y[val_idx]

        model.fit(x_train, y_train)

        metric = evaluate_multiclass_model(
            model,
            x_val,
            y_val,
            val_idx,
            fold,
            result_dir=RESULTS,
            data_model=model_name,
            classes=["DOMICILE", "REEDUC_TRANSFERT", "DECES"],
            num_patients=NUM_PATIENTS,
            time_opt="TS",
        )

        all_metrics.append(metric)

        current_score = metric.loc["MACRO", "AUC"]

        if current_score > best_score:
            best_score = current_score
            best_fold = fold
            best_model = model

    model_path = (
        f"{RESULTS}/models/"
        f"{model_name}_best_fold{best_fold}_auc_{best_score:.4f}.joblib"
    )

    joblib.dump(best_model, model_path)

    print(
        f"Saved best {model_name} model (fold={best_fold}, macro_auc={best_score:.4f})"
    )

    panel = pd.concat(all_metrics)
    metrics_mean = panel.groupby(level=0).mean()
    metrics_mean.index.name = "MEAN"
    metrics_std = panel.groupby(level=0).std()
    metrics_std.index.name = "STD"

    mean_std_metrics(
        metrics_mean, metrics_std, ["DOMICILE", "REEDUC_TRANSFERT", "DECES"]
    ).to_csv(
        f"{RESULTS}/metrics_TS_{NUM_PATIENTS}_mean_std.csv",
        sep="\t",
        index=False,
        mode="a",
    )
    metrics_mean.to_csv(f"{RESULTS}/metrics_TS_{NUM_PATIENTS}.csv", mode="a")
    metrics_std.to_csv(f"{RESULTS}/metrics_TS_{NUM_PATIENTS}.csv", mode="a")

# %%
import shap
import joblib

model_name = "xgboost"
model = joblib.load(
    f"exports/neurovasc_v2/graph/metrics_{NUM_PATIENTS}/{model_name}/models/{model_name}_best_fold2_auc_0.8900.joblib"
)

explainer = shap.TreeExplainer(model)

# %%
import shap
import matplotlib.pyplot as plt

shap_values = explainer.shap_values(X)

for class_idx, class_name in enumerate(["DOMICILE", "REEDUC_TRANSFERT", "DECES"]):
    shap.summary_plot(
        shap_values[:, :, class_idx],
        X,
        feature_names=feature_names,
        show=False,
    )

    plt.savefig(
        f"{EXPORT_DIR}/metrics_{NUM_PATIENTS}/{model_name}/shap_class_{class_name}.png",
        bbox_inches="tight",
        dpi=300,
    )
    plt.close()

# %%
sample_idx = 0

shap_exp = explainer(X)

waterfall_exp = shap.Explanation(
    values=shap_exp.values[sample_idx, :, class_idx],
    base_values=shap_exp.base_values[sample_idx, class_idx],
    data=X.iloc[sample_idx],
    feature_names=feature_names,
)

shap.plots.waterfall(
    waterfall_exp,
    max_display=20,
    show=False,
)

plt.savefig(
    f"{EXPORT_DIR}/metrics_{NUM_PATIENTS}/{model_name}/shap_waterfall_sample{sample_idx}.png",
    bbox_inches="tight",
    dpi=300,
)

plt.close()

# %%
force_plot = shap.force_plot(
    base_value=shap_exp.base_values[sample_idx, class_idx],
    shap_values=shap_exp.values[sample_idx, :, class_idx],
    features=X.iloc[sample_idx],
    feature_names=feature_names,
    matplotlib=True,
    show=False,
)

plt.savefig(
    f"{EXPORT_DIR}/metrics_{NUM_PATIENTS}/{model_name}/shap_force_sample{sample_idx}.png",
    bbox_inches="tight",
    dpi=300,
)

plt.close()

# %%
from rdflib import Graph
from NEUROVASC.utils.metrics import compute_MEDS_graph_metrics, save_stats_json
import glob

g = Graph()

for path in glob.glob(f"{EXPORT_DIR}/meds_{NUM_PATIENTS}/*.nt"):
    g.parse(path, format="nt")

stats = compute_MEDS_graph_metrics(
    MEDS_ETL_output_path=N2_ETL_OUTPUT,
    graph=g,
)

save_stats_json(stats, f"{N2_ETL_OUTPUT}/metrics/all_metrics.json")

# %%
ROOT = "NEUROVASC2/MEDS_cohort"

df = (
    pl.scan_parquet(f"{ROOT}/data/**/0.parquet")
    .select(["subject_id", "code", "time", "numeric_value"])
    .collect(engine="streaming")
)

# %%
import polars as pl
from tqdm import tqdm
from rdflib import Graph
import os

from NEUROVASC2.sphn_mapping import (
    SEMANTIC_MAP,
    SemanticEvent,
    make_id,
    parse_code,
    render_event,
)

ROOT = "NEUROVASC2/MEDS_cohort"

ROWS_PER_FILE = 100_000

df = (
    pl.scan_parquet(f"{ROOT}/data/**/0.parquet")
    .select(["subject_id", "code", "time", "numeric_value"])
    .collect(engine="streaming")
)

total_rows = len(df)

file_index = 0
rows_in_file = 0

NUM_PATIENTS = len(df.group_by(pl.col("subject_id")).len())

OUTPUT_FOLDER = f"exports/neurovasc_v2/graph/sphn_pc_{NUM_PATIENTS}"

os.makedirs(OUTPUT_FOLDER, exist_ok=True)

f = open(f"{OUTPUT_FOLDER}/part_{file_index:03d}.nt", "w")

for row in tqdm(df.iter_rows(), total=total_rows, desc="Generating RDF"):
    if rows_in_file >= ROWS_PER_FILE:
        f.close()

        file_index += 1
        rows_in_file = 0

        f = open(f"{OUTPUT_FOLDER}/part_{file_index:03d}.nt", "w")

    variable, value = parse_code(row[1])

    if variable not in SEMANTIC_MAP:
        continue

    meta = SEMANTIC_MAP[variable]

    time = row[2]

    event_id = make_id(
        row[0],
        variable,
        time,
        value,
        row[3],
    )

    event = SemanticEvent(
        patient_id=row[0],
        variable=variable,
        numeric_value=row[3],
        time=time,
        template_name=meta,
        code=row[1],
        label=variable,
        event_id=event_id,
    )

    ev = render_event(event)

    ev = Graph().parse(data=ev, format="nt").serialize(format="nt")

    f.write(ev)

    rows_in_file += 1

f.close()

print("RDF generation complete.")
